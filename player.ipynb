# %%
class Player():
    isim="iclal"
    guc=55

# %%
Player.isim
# Out:
# 'iclal'

# %%
Player.guc
# Out:
# 55

# %%
Player.isim="ayşe"

# %%
Player.isim
# Out:
# 'ayşe'

# %%
class Insan():
    def __init__(self,isim,guc):
        self.name=isim
        self.damage=guc
    def setName(self,isim):
        self.name=isim

# %%
selin=Insan("selin",90)

# %%
selin.name
# Out:
# 'selin'

# %%
selin.setName("elif")

# %%
selin.name
# Out:
# 'elif'
