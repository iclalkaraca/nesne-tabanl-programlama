# %%
def f():
    print("merhaba dünya")

# %%
f()
# Out:
# merhaba dünya

# %%
def f(x,y):
    toplam =x+y
    print("toplam:",toplam)

# %%
f(3,5)
# Out:
# toplam: 8

# %%
def f(*args):
    return args[0]

# %%
f(1,2,3)
# Out:
# 1

# %%
def f(*args):
    toplam = 0
    for i in args:
        toplam += 1
    return toplam
