# %%
class Dusman():
    def __init__(self):
        self.can=100
        self.guc=40
    def vur(self,oyuncu):
        oyuncu.can-=self.guc     #oyuncu.can = oyuncu.can - self.guc

# %%
class Oyuncu():
    def __init__(self):
        self.can=500
        self.guc=100
    def vur(self,dusman):
        dusman.can-=self.guc

# %%
player = Oyuncu()

# %%
player.can
# Out:
# 500

# %%
player.guc
# Out:
# 100

# %%
dusmanlar=[]

for i in range(10):        #coklu örnekleme
    dusmanlar.append(Dusman))
# Out:
#   Cell In[33], line 4
#     dusmanlar.append(Dusman))
#                             ^
# SyntaxError: unmatched ')'
