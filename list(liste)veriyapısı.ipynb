# %%
liste = []   #liste = list()

# %%
dir(list())   #dir(liste)  #metodlara ulaşmak için
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
for i in  dir(list()):
    if i[0] != "_":
        print(i)
# Out:
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse
# sort

# %%
liste.append("iclal")     #append listeye eleman eklemek için

# %%
liste
# Out:
# ['iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal']

# %%
liste += ["sevgi"]

# %%
liste
# Out:
# ['iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'sevgi']

# %%
liste.index("sevgi")
# Out:
# 9

# %%
liste.append("iclal")

# %%
liste.append(1)

# %%
liste
# Out:
# ['iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'iclal',
#  'sevgi',
#  'iclal',
#  1]

# %%
liste.count("iclal")    #kaç defa geçtiğini bulmak için
# Out:
# 10

# %%
len(liste)
# Out:
# 12

# %%
liste[0]
# Out:
# 'iclal'

# %%
liste.pop()
# Out:
# 'iclal'

# %%
for i in dir(list()):
    if "_" not in i:
        print(i)
# Out:
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse
# sort

# %%
a=list()
a.append(1)

# %%
a
# Out:
# [1]

# %%
b = a.copy()

# %%
id(a)
# Out:
# 2512203344768

# %%
id(b)
# Out:
# 2512203395136

# %%
a.append(2)

# %%
a
# Out:
# [1, 2]
