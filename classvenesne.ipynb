# %%
#class nedir

# %%
for i in dir(list()):
    if "_" not in i:
        print(i)
# Out:
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse
# sort

# %%
liste = ["elma","armut","muz"]

# %%
liste.insert(1,"kavun")

# %%
liste
# Out:
# ['elma', 'kavun', 'armut', 'muz']

# %%
#nesne(object) nedir

# %%
a=list()

# %%
a.append("bilgisayar")
a.append("fare")

# %%
a
# Out:
# ['bilgisayar', 'fare']

# %%
b=a

# %%
b.append("monitör")

# %%
b
# Out:
# ['bilgisayar', 'fare', 'monitör']

# %%
c=a.copy()

# %%
c.append("şapka")

# %%
c
# Out:
# ['bilgisayar', 'fare', 'monitör', 'şapka']

# %%
a
# Out:
# ['bilgisayar', 'fare', 'monitör']

# %%
b
# Out:
# ['bilgisayar', 'fare', 'monitör']
